# %%
from QNetwork import Agent

import gym
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
agent = Agent(gym.make('FrozenLake-v0'), max_episodes=3000, max_steps=99, lr=0.1, gamma=0.99)
steps, rewards = agent.run_learner()
# Out:
# [2017-05-28 21:44:47,393] Making new env: FrozenLake-v0
# Percent of succesful episodes: 0.4846666666666667%
# Percent of succesful last 50: 0.56%

# %%
pd.DataFrame(rewards).rolling(50).mean().plot()

# %%
pd.DataFrame(steps).rolling(50).mean().plot()
